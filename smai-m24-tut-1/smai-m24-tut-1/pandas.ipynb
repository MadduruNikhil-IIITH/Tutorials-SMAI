# %%
# !pip3 install pandas
# !pip3 install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.9 kB ? eta -:--:--
#      ------------------- ------------------- 81.9/165.9 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB 6.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/8.0 MB 12.2 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/8.0 MB 13.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/8.0 MB 11.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.3/8.0 MB 10.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/8.0 MB 10.8 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# IMDB-Movies-Data.csv
base_url = 'https://gist.githubusercontent.com/alti-tude/710cb9d4dfc7ebcd0afb9cf93d8f6a8d/raw/574730ba009e69b81d6c79f2fef2c3dd5145db0a/'

# %%
data = {
    'apples':[3,2,0,1],
    'oranges':[0,3,7,2]
}

# %%
purchases = pd.DataFrame(data)
purchases.head() # Display rows from the top (Default: top 5)
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases.set_index(np.array(['June','Robert','Lily','David'])) # manually change index of rows
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
df = pd.read_csv(base_url+'purchases.csv') # Read csv file and transform into a Dataframe

df.head()
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
df = pd.read_csv(base_url+'purchases.csv',index_col=0) # using first column for indexing

df.head()
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
df = pd.read_json(base_url+'purchases.json') # json file -> dataframe

df.head()
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
movies_df = pd.read_csv(base_url+'IMDB-Movie-Data.csv',index_col='Title') # selecting column by name instead of index

# %%
movies_df.columns # get all the columns of the dataframe
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
# Generates descriptive statistics, that describes the distribution of the data
# The output will vary depending on what is provided
movies_df.describe
# Out:
# <bound method NDFrame.describe of                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.tail() # display rows from the botton (Default: last 5)
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
# Prints summary of dataframe
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
movies_df.shape # shape of the dataframe (rows, columns)
# Out:
# (1000, 11)

# %%
temp_df = movies_df.append(movies_df) # appending dataframe by itself (thus doubling its size)
temp_df.shape
# Out:
# (2000, 11)

# %%
temp_df.drop_duplicates()
temp_df.shape
# Out:
# (2000, 11)

# %%
movies_df.rename(columns={
    'Revenue (Millions)':'revenue_millions',
    'Runtime (Minutes)':'runtime'
})
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
movies_df.columns = ['rank','genre','description','director','actors','year','runtime','rating','votes','revenue_millions','metascore']
movies_df.head()
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df.isna() # returns boolean where None and NaN gets mapped to True, else False
# Out:
#                           rank  genre  description  director  actors   year  \
# Title
# Guardians of the Galaxy  False  False        False     False   False  False
# Prometheus               False  False        False     False   False  False
# Split                    False  False        False     False   False  False
# Sing                     False  False        False     False   False  False
# Suicide Squad            False  False        False     False   False  False
# ...                        ...    ...          ...       ...     ...    ...
# Secret in Their Eyes     False  False        False     False   False  False
# Hostel: Part II          False  False        False     False   False  False
# Step Up 2: The Streets   False  False        False     False   False  False
# Search Party             False  False        False     False   False  False
# Nine Lives               False  False        False     False   False  False
#
# ...

# %%
movies_df.dropna()
# Out:
#                           rank                     genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
revenue_df = movies_df['revenue_millions']
revenue_df
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Secret in Their Eyes          NaN
# Hostel: Part II             17.54
# Step Up 2: The Streets      58.01
# Search Party                  NaN
# Nine Lives                  19.64
# Name: revenue_millions, Length: 1000, dtype: float64

# %%
revenue_df.fillna(revenue_df.mean())
# Out:
# Title
# Guardians of the Galaxy    333.130000
# Prometheus                 126.460000
# Split                      138.120000
# Sing                       270.320000
# Suicide Squad              325.020000
#                               ...
# Secret in Their Eyes        82.956376
# Hostel: Part II             17.540000
# Step Up 2: The Streets      58.010000
# Search Party                82.956376
# Nine Lives                  19.640000
# Name: revenue_millions, Length: 1000, dtype: float64

# %%
prom = movies_df.loc['Prometheus'] # access a group of rows by index or a boolean array
prom
# Out:
# rank                                                                2
# genre                                        Adventure,Mystery,Sci-Fi
# description         Following clues to the origin of mankind, a te...
# director                                                 Ridley Scott
# actors              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# year                                                             2012
# runtime                                                           124
# rating                                                            7.0
# votes                                                          485820
# revenue_millions                                               126.46
# metascore                                                        65.0
# Name: Prometheus, dtype: object

# %%
prom = movies_df.iloc[1] # purely integer-location based indexing for selection bt position
prom
# Out:
# rank                                                                2
# genre                                        Adventure,Mystery,Sci-Fi
# description         Following clues to the origin of mankind, a te...
# director                                                 Ridley Scott
# actors              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# year                                                             2012
# runtime                                                           124
# rating                                                            7.0
# votes                                                          485820
# revenue_millions                                               126.46
# metascore                                                        65.0
# Name: Prometheus, dtype: object

# %%
movies_df.iloc[1:4] # slicing
# Out:
#             rank                     genre  \
# Title
# Prometheus     2  Adventure,Mystery,Sci-Fi
# Split          3           Horror,Thriller
# Sing           4   Animation,Comedy,Family
#
#                                                   description  \
# Title
# Prometheus  Following clues to the origin of mankind, a te...
# Split       Three girls are kidnapped by a man with a diag...
# Sing        In a city of humanoid animals, a hustling thea...
#
#                         director  \
# Title
# Prometheus          Ridley Scott
# Split         M. Night Shyamalan
# Sing        Christophe Lourdelet
#
#                                                        actors  year  runtime  \
# Title
# Prometheus  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012      124
# Split       James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016      117
# Sing        Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016      108
#
# ...

# %%
movies_df.loc['Prometheus':'Sing'] # slicing using lables
# Out:
#             rank                     genre  \
# Title
# Prometheus     2  Adventure,Mystery,Sci-Fi
# Split          3           Horror,Thriller
# Sing           4   Animation,Comedy,Family
#
#                                                   description  \
# Title
# Prometheus  Following clues to the origin of mankind, a te...
# Split       Three girls are kidnapped by a man with a diag...
# Sing        In a city of humanoid animals, a hustling thea...
#
#                         director  \
# Title
# Prometheus          Ridley Scott
# Split         M. Night Shyamalan
# Sing        Christophe Lourdelet
#
#                                                        actors  year  runtime  \
# Title
# Prometheus  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012      124
# Split       James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016      117
# Sing        Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016      108
#
# ...

# %%
movies_df[movies_df['director'] == 'Ridley Scott']  # boolean array indexing
# Out:
#                         rank                     genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# The Martian             An astronaut becomes stranded on Mars after hi...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
# ...

# %%
movies_df[movies_df['rating']>=8.6].head()
# Out:
#                  rank                    genre  \
# Title
# Interstellar       37   Adventure,Drama,Sci-Fi
# The Dark Knight    55       Action,Crime,Drama
# Inception          81  Action,Adventure,Sci-Fi
# Kimi no na wa      97  Animation,Drama,Fantasy
# Dangal            118   Action,Biography,Drama
#
#                                                        description  \
# Title
# Interstellar     A team of explorers travel through a wormhole ...
# The Dark Knight  When the menace known as the Joker wreaks havo...
# Inception        A thief, who steals corporate secrets through ...
# Kimi no na wa    Two strangers find themselves linked in a biza...
# Dangal           Former wrestler Mahavir Singh Phogat and his t...
#
#                           director  \
# Title
# Interstellar     Christopher Nolan
# The Dark Knight  Christopher Nolan
# Inception        Christopher Nolan
# Kimi no na wa       Makoto Shinkai
# Dangal               Nitesh Tiwari
#
# ...

# %%
movies_df[movies_df['genre'].str.contains('Drama')]
# Out:
#                         rank                    genre  \
# Title
# La La Land                 7       Comedy,Drama,Music
# Passengers                10  Adventure,Drama,Romance
# Hidden Figures            12  Biography,Drama,History
# Colossal                  15      Action,Comedy,Drama
# Hacksaw Ridge             17  Biography,Drama,History
# ...                      ...                      ...
# Selma                    990  Biography,Drama,History
# Taare Zameen Par         992       Drama,Family,Music
# Take Me Home Tonight     993     Comedy,Drama,Romance
# Secret in Their Eyes     996      Crime,Drama,Mystery
# Step Up 2: The Streets   998      Drama,Music,Romance
#
#                                                               description  \
# Title
# La La Land              A jazz pianist falls for an aspiring actress i...
# Passengers              A spacecraft traveling to a distant colony pla...
# Hidden Figures          The story of a team of female African-American...
# ...

# %%
movies_df[
    (movies_df['rating']>=8.6)
    &(movies_df['revenue_millions']>=movies_df['revenue_millions'].quantile(0.25))
]
# Out:
#                  rank                    genre  \
# Title
# Interstellar       37   Adventure,Drama,Sci-Fi
# The Dark Knight    55       Action,Crime,Drama
# Inception          81  Action,Adventure,Sci-Fi
#
#                                                        description  \
# Title
# Interstellar     A team of explorers travel through a wormhole ...
# The Dark Knight  When the menace known as the Joker wreaks havo...
# Inception        A thief, who steals corporate secrets through ...
#
#                           director  \
# Title
# Interstellar     Christopher Nolan
# The Dark Knight  Christopher Nolan
# Inception        Christopher Nolan
#
#                                                             actors  year  \
# Title
# Interstellar     Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# The Dark Knight  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# Inception        Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
#
# ...

# %%
def rating_function(x):
    return 'good' if x>=8.0 else 'bad'

# %%
movies_df['rating category'] = movies_df['rating'].apply(rating_function)
movies_df
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df['rating category'] = movies_df['rating'].apply(lambda x: 'good' if x>=8.0 else 'bad')
movies_df
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# # Exampes

# %%
music_df = pd.read_csv(base_url+'MusicTop50.csv',index_col=0)
music_df.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 1                         Se�orita   Shawn Mendes    canadian pop
# 2                            China       Anuel AA  reggaeton flow
# 3    boyfriend (with Social House)  Ariana Grande       dance pop
# 4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability..db..  Loudness..  Liveness.  \
# 1             117.0    55.0                  76          -6        8.0
# 2             105.0    81.0                  79          -4        8.0
# 3             190.0    80.0                  40          -4       16.0
# 4              93.0    65.0                  64          -8        8.0
# 5               NaN    65.0                  58          -4       11.0
#
#    Valence ()  Length  Acousticness  Speechiness  Popularity
# 1        75.0   191.0             4            3        79.0
# ...

# %%
music_df.tail()
# Out:
#                                        Track.Name       Artist.Name    Genre  \
# 46                                One Thing Right        Marshmello  brostep
# 47                                      Te Robar�         Nicky Jam    latin
# 48                                        Happier        Marshmello  brostep
# 49                                  Call You Mine  The Chainsmokers      edm
# 50  Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran      pop
#
#     Beats.Per.Minute  Energy  Danceability..db..  Loudness..  Liveness.  \
# 46              88.0    62.0                  66          -2        NaN
# 47             176.0    75.0                  67          -4        8.0
# 48             100.0    79.0                  69          -3       17.0
# 49             104.0    70.0                  59          -6       41.0
# 50              95.0    79.0                  75          -6        7.0
#
#     Valence ()  Length  Acousticness  Speechiness  Popularity
# ...

# %%
music_df.columns
# Out:
# Index(['Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute', 'Energy',
#        'Danceability..db..', 'Loudness..', 'Liveness.', 'Valence ()', 'Length',
#        'Acousticness', 'Speechiness', 'Popularity'],
#       dtype='object')

# %%
music_df.columns = ['name', 'artist', 'genre', 'bpm', 'energy','danceability', 'loudness', 'liveness', 'valence', 'length','acousticness', 'speechiness', 'popularity']
music_df
# Out:
#                                                  name            artist  \
# 1                                            Se�orita      Shawn Mendes
# 2                                               China          Anuel AA
# 3                       boyfriend (with Social House)     Ariana Grande
# 4                     Beautiful People (feat. Khalid)        Ed Sheeran
# 5                         Goodbyes (Feat. Young Thug)       Post Malone
# 6                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 7                                              Ransom         Lil Tecca
# 8                                   How Do You Sleep?         Sam Smith
# 9                               Old Town Road - Remix         Lil Nas X
# 10                                            bad guy     Billie Eilish
# 11                                           Callaita         Bad Bunny
# 12              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
music_df.info
# Out:
# <bound method DataFrame.info of                                                  name            artist  \
# 1                                            Se�orita      Shawn Mendes
# 2                                               China          Anuel AA
# 3                       boyfriend (with Social House)     Ariana Grande
# 4                     Beautiful People (feat. Khalid)        Ed Sheeran
# 5                         Goodbyes (Feat. Young Thug)       Post Malone
# 6                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 7                                              Ransom         Lil Tecca
# 8                                   How Do You Sleep?         Sam Smith
# 9                               Old Town Road - Remix         Lil Nas X
# 10                                            bad guy     Billie Eilish
# 11                                           Callaita         Bad Bunny
# 12              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
music_df.fillna(music_df.mean())
# Out:
# <ipython-input-41-8f4044306c71>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   music_df.fillna(music_df.mean())
#                                                  name            artist  \
# 1                                            Se�orita      Shawn Mendes
# 2                                               China          Anuel AA
# 3                       boyfriend (with Social House)     Ariana Grande
# 4                     Beautiful People (feat. Khalid)        Ed Sheeran
# 5                         Goodbyes (Feat. Young Thug)       Post Malone
# 6                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 7                                              Ransom         Lil Tecca
# 8                                   How Do You Sleep?         Sam Smith
# ...

# %%
music_df.fillna(music_df.median())
# Out:
# <ipython-input-42-128949eb9497>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   music_df.fillna(music_df.median())
#                                                  name            artist  \
# 1                                            Se�orita      Shawn Mendes
# 2                                               China          Anuel AA
# 3                       boyfriend (with Social House)     Ariana Grande
# 4                     Beautiful People (feat. Khalid)        Ed Sheeran
# 5                         Goodbyes (Feat. Young Thug)       Post Malone
# 6                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 7                                              Ransom         Lil Tecca
# 8                                   How Do You Sleep?         Sam Smith
# ...

# %%
music_df.dropna()
# Out:
#                                                  name            artist  \
# 1                                            Se�orita      Shawn Mendes
# 2                                               China          Anuel AA
# 3                       boyfriend (with Social House)     Ariana Grande
# 4                     Beautiful People (feat. Khalid)        Ed Sheeran
# 6                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 8                                   How Do You Sleep?         Sam Smith
# 9                               Old Town Road - Remix         Lil Nas X
# 10                                            bad guy     Billie Eilish
# 13                                  Someone You Loved     Lewis Capaldi
# 14                                 Otro Trago - Remix              Sech
# 15           Money In The Grave (Drake ft. Rick Ross)             Drake
# 16                          No Guidance (feat. Drake)       Chris Brown
# ...

# %%
least_pop_song_artist = music_df[music_df['popularity'] == music_df['popularity'].min()].iloc[0]['artist']

# %%
least_pop_song_artist
# Out:
# 'Shawn Mendes'

# %%
artist_folio = music_df[music_df['artist'] == least_pop_song_artist]

# %%
artist_folio[artist_folio['loudness']==artist_folio['loudness'].max()]['name']
# Out:
# 26    If I Can't Have You
# Name: name, dtype: object

# %%
names,counts = np.unique(music_df['artist'],return_counts=True)

# %%
df2 = pd.DataFrame.from_dict(dict(zip(names,counts)),orient='index')

# %%
df2
# Out:
#                   0
# Ali Gatie         1
# Anuel AA          1
# Ariana Grande     2
# Bad Bunny         1
# Billie Eilish     2
# Chris Brown       1
# DJ Snake          1
# Daddy Yankee      1
# Drake             1
# Ed Sheeran        4
# J Balvin          2
# Jhay Cortez       1
# Jonas Brothers    1
# Katy Perry        1
# Khalid            1
# Kygo              1
# Lady Gaga         1
# Lauv              1
# Lewis Capaldi     1
# Lil Nas X         2
# Lil Tecca         1
# Lizzo             1
# Lunay             1
# MEDUZA            1
# Maluma            1
# Marshmello        2
# Martin Garrix     1
# Nicky Jam         1
# Post Malone       2
# ROSAL�A           1
# Sam Smith         1
# Sech              2
# Shawn Mendes      2
# Taylor Swift      1
# The Chainsmokers  2
# Tones and I       1
# Y2K               1
# Young Thug        1

# %% [markdown]
# #Tasks

# %% [markdown]
# ##Task 1

# %%
least_pop_song_artists = music_df[music_df['popularity'] == music_df['popularity'].min()]['artist']
least_pop_song_artists
# Out:
# 26    Shawn Mendes
# Name: artist, dtype: object

# %% [markdown]
# ##Task 2

# %%
most_pop_song_artists = music_df[music_df['popularity'] == music_df['popularity'].max()]['artist']
most_pop_song_artists
# Out:
# 10    Billie Eilish
# Name: artist, dtype: object

# %% [markdown]
# ##Task 3

# %%
df3=music_df.groupby('genre').count()['artist']

print(df3)
# Out:
# genre
# atl hip hop         1
# australian pop      1
# big room            1
# boy band            1
# brostep             2
# canadian hip hop    3
# canadian pop        2
# country rap         2
# dance pop           8
# dfw rap             2
# edm                 3
# electropop          2
# escape room         1
# latin               5
# panamanian pop      2
# pop                 7
# pop house           1
# r&b en espanol      1
# reggaeton           2
# reggaeton flow      2
# trap music          1
# Name: artist, dtype: int64

# %% [markdown]
# ##Task 4

# %%
print(music_df[(music_df['danceability']>70) &(music_df['energy']<55)]['artist'].tolist())
# Out:
# ['Drake', 'Post Malone', 'Y2K', 'Ali Gatie', 'Ariana Grande', 'Khalid']

# %% [markdown]
# ##Task 5

# %%
music_df['loudness'] = music_df['loudness'].apply(lambda x: 0 if x<0 else x)
music_df.head()
# Out:
#                               name         artist           genre    bpm  \
# 1                         Se�orita   Shawn Mendes    canadian pop  117.0
# 2                            China       Anuel AA  reggaeton flow  105.0
# 3    boyfriend (with Social House)  Ariana Grande       dance pop  190.0
# 4  Beautiful People (feat. Khalid)     Ed Sheeran             pop   93.0
# 5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap    NaN
#
#    energy  danceability  loudness  liveness  valence  length  acousticness  \
# 1    55.0            76         0       8.0     75.0   191.0             4
# 2    81.0            79         0       8.0     61.0   302.0             8
# 3    80.0            40         0      16.0     70.0   186.0            12
# 4    65.0            64         0       8.0     55.0   198.0            12
# 5    65.0            58         0      11.0     18.0   175.0            45
#
#    speechiness  popularity
# 1            3        79.0
# ...

# %% [markdown]
# ##Task 6

# %%
above_avg_df=music_df[music_df['danceability']>music_df['danceability'].mean()]
above_avg_df
# Out:
#                                                  name          artist  \
# 1                                            Se�orita    Shawn Mendes
# 2                                               China        Anuel AA
# 6                   I Don't Care (with Justin Bieber)      Ed Sheeran
# 7                                              Ransom       Lil Tecca
# 9                               Old Town Road - Remix       Lil Nas X
# 12              Loco Contigo (feat. J. Balvin & Tyga)        DJ Snake
# 14                                 Otro Trago - Remix            Sech
# 15           Money In The Grave (Drake ft. Rick Ross)           Drake
# 17                                         LA CANCI�N        J Balvin
# 18      Sunflower - Spider-Man: Into the Spider-Verse     Post Malone
# 19                                             Lalala             Y2K
# 20                                        Truth Hurts           Lizzo
# ...

# %% [markdown]
# ##Task 7

# %%
music_df['score'] = music_df['energy']+music_df['popularity']
music_df.head()
# Out:
#                               name         artist           genre    bpm  \
# 1                         Se�orita   Shawn Mendes    canadian pop  117.0
# 2                            China       Anuel AA  reggaeton flow  105.0
# 3    boyfriend (with Social House)  Ariana Grande       dance pop  190.0
# 4  Beautiful People (feat. Khalid)     Ed Sheeran             pop   93.0
# 5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap    NaN
#
#    energy  danceability  loudness  liveness  valence  length  acousticness  \
# 1    55.0            76         0       8.0     75.0   191.0             4
# 2    81.0            79         0       8.0     61.0   302.0             8
# 3    80.0            40         0      16.0     70.0   186.0            12
# 4    65.0            64         0       8.0     55.0   198.0            12
# 5    65.0            58         0      11.0     18.0   175.0            45
#
#    speechiness  popularity  score
# 1            3        79.0  134.0
# ...

# %% [markdown]
# ##Task 8

# %%
music_df.sort_values('score')
# Out:
#                                                  name            artist  \
# 32                                            7 rings     Ariana Grande
# 44                                               Talk            Khalid
# 43                                            Shallow         Lady Gaga
# 19                                             Lalala               Y2K
# 16                          No Guidance (feat. Drake)       Chris Brown
# 13                                  Someone You Loved     Lewis Capaldi
# 1                                            Se�orita      Shawn Mendes
# 40  fuck, i'm lonely (with Anne-Marie) - from �13 ...              Lauv
# 25                       bad guy (with Justin Bieber)     Billie Eilish
# 31                                           Takeaway  The Chainsmokers
# 28                                           It's You         Ali Gatie
# 10                                            bad guy     Billie Eilish
# ...
